# %% [markdown]
# ## Data Prep -- XML to CSV

# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET

# %%
health_date = ET.parse('export.xml')

# %%
root = health_date.getroot()
root
# Out:
# <Element 'HealthData' at 0x122d398f0>

# %%
root.tag
# Out:
# 'HealthData'

# %%
root.attrib
# Out:
# {'locale': 'en_CN'}

# %%
## look at a sample of the child nodes

i = 0
for child in root:
    print(child.tag)
    print(child.attrib)
    #print(child.attrib.get("type"))
    #print(child.attrib.get("sourceName"))
    i += 1
    if i >= 20:
        break

# %%
data_type_dic = {}

for child in root:
    if child.tag not in data_type_dic:
        data_type_dic[child.tag] = 0
    else:
        data_type_dic[child.tag] += 1

# %%
print(data_type_dic)
# Out:
# {'ExportDate': 0, 'Me': 0, 'Record': 627410, 'Workout': 159, 'ActivitySummary': 183}

# %%
### parse the three type of records into three pandas df

records_cols = ["type", "sourceName", "unit", "creationDate", "startDate", "endDate", "value"]
records_rows = []

workout_cols = ["type", "duration", "durationUnit", "totalDistance", "totalDistanceUnit", 
                "totalEnergyBurned", "totalEnergyBurnedUnit", "sourceName",
                "creationDate", "startDate", "endDate"]
workout_rows = []

summary_cols = ["date", "activeEnergyBurned", "activeEnergyBurnedGoal", "activeEnergyBurnedUnit",
               "exerciseTime", "exerciseTimeGoal", "standHours", "standHoursGoal"]
summary_rows = []

for node in root: 
    if node.tag == 'Record':
        r_type = node.attrib.get("type")
        r_sourceName = node.attrib.get("sourceName")
        r_unit = node.attrib.get("unit")
        r_creationDate = node.attrib.get("creationDate")
        r_startDate = node.attrib.get("startDate")
        r_endDate = node.attrib.get("endDate")
        r_value = node.attrib.get("value")

        records_rows.append({"type": r_type, "sourceName": r_sourceName, 
                             "unit": r_unit, "creationDate": r_creationDate,
                             "startDate": r_startDate, "endDate": r_endDate,
                             "value": r_value
                            })
    
    elif node.tag == 'Workout':
        w_type = node.attrib.get("workoutActivityType")
        w_duration = node.attrib.get("duration")
        w_durationUnit = node.attrib.get("durationUnit")
        w_totalDistance = node.attrib.get("totalDistance")
        w_totalDistanceUnit = node.attrib.get("totalDistanceUnit")
        w_totalEnergyBurned = node.attrib.get("totalEnergyBurned")
        w_totalEnergyBurnedUnit = node.attrib.get("totalEnergyBurnedUnit")
        w_sourceName = node.attrib.get("sourceName")
        w_unit = node.attrib.get("gunit")
        w_creationDate = node.attrib.get("creationDate")
        w_startDate = node.attrib.get("startDate")
        w_endDate = node.attrib.get("endDate")

        workout_rows.append({"type": w_type, 
                             "duration": w_duration, "durationUnit": w_durationUnit, 
                             "totalDistance": w_totalDistance, "totalDistanceUnit": w_totalDistanceUnit,
                             "totalEnergyBurned": w_totalEnergyBurned, "totalEnergyBurnedUnit": w_totalEnergyBurnedUnit,
                             "sourceName": r_sourceName, "creationDate": r_creationDate,
                             "startDate": r_startDate, "endDate": r_endDate
                            })
    
    elif node.tag == 'ActivitySummary':
        s_date = node.attrib.get("dateComponents")
        s_activeEnergyBurned = node.attrib.get("activeEnergyBurned")
        s_activeEnergyBurnedGoal = node.attrib.get("activeEnergyBurnedGoal")
        s_activeEnergyBurnedUnit = node.attrib.get("activeEnergyBurnedUnit")
        s_appleExerciseTime = node.attrib.get("appleExerciseTime")
        s_appleExerciseTimeGoal = node.attrib.get("appleExerciseGoal")
        s_appleStandHours = node.attrib.get("appleStandHours")
        s_appleStandHoursGoal = node.attrib.get("appleStandHoursGoal")

        summary_rows.append({"date": s_date,
                            "activeEnergyBurned": s_activeEnergyBurned,
                            "activeEnergyBurnedGoal": s_activeEnergyBurnedGoal,
                            "activeEnergyBurnedUnit": s_activeEnergyBurnedUnit,
                            "exerciseTime": s_appleExerciseTime, "exerciseTimeGoal": s_appleExerciseTimeGoal,
                            "standHours": s_appleStandHours, "standHoursGoal": s_appleStandHoursGoal})

record_df = pd.DataFrame(records_rows, columns = records_cols)
workout_df = pd.DataFrame(workout_rows, columns = workout_cols)
summary_df = pd.DataFrame(summary_rows, columns = summary_cols)

# %%
record_df.head(10)

# %%
record_df['type'].value_counts()
# Out:
# HKQuantityTypeIdentifierActiveEnergyBurned                  242019
# HKQuantityTypeIdentifierBasalEnergyBurned                   101057
# HKQuantityTypeIdentifierStepCount                            85004
# HKQuantityTypeIdentifierHeartRate                            84482
# HKQuantityTypeIdentifierDistanceWalkingRunning               81194
# HKQuantityTypeIdentifierAppleExerciseTime                     6541
# HKQuantityTypeIdentifierFlightsClimbed                        6480
# HKQuantityTypeIdentifierAppleStandTime                        5943
# HKQuantityTypeIdentifierEnvironmentalAudioExposure            5850
# HKCategoryTypeIdentifierAppleStandHour                        4149
# HKCategoryTypeIdentifierSleepAnalysis                         1573
# HKQuantityTypeIdentifierHeadphoneAudioExposure                1123
# HKQuantityTypeIdentifierHeartRateVariabilitySDNN               827
# HKCategoryTypeIdentifierMenstrualFlow                          519
# HKQuantityTypeIdentifierRestingHeartRate                       178
# HKQuantityTypeIdentifierWalkingHeartRateAverage                171
# HKQuantityTypeIdentifierBodyMass                                54
# HKQuantityTypeIdentifierBodyMassIndex                           53
# HKQuantityTypeIdentifierBodyFatPercentage                       51
# HKQuantityTypeIdentifierLeanBodyMass                            51
# HKCategoryTypeIdentifierMindfulSession                          36
# HKCategoryTypeIdentifierMenstrualSymptomBreastTenderness        16
# HKCategoryTypeIdentifierMenstrualSymptomTiredness                9
# HKCategoryTypeIdentifierAudioExposureEvent                       7
# HKQuantityTypeIdentifierVO2Max                                   7
# HKCategoryTypeIdentifierMenstrualSymptomAbdominalCramps          4
# HKCategoryTypeIdentifierMenstrualSymptomLowerBackPain            4
# HKQuantityTypeIdentifierHeight                                   3
# HKCategoryTypeIdentifierMenstrualSymptomDiarrhea                 3
# HKCategoryTypeIdentifierMenstrualSymptomAppetiteChanges          2
# HKCategoryTypeIdentifierMenstrualSymptomAcne                     1
# Name: type, dtype: int64

# %%
record_df.to_csv('all_health_record.csv', index=False)

# %%
heart_rate_df = record_df.loc[record_df['type'].isin(["HKQuantityTypeIdentifierHeartRate", 
                                                      "HKQuantityTypeIdentifierRestingHeartRate", 
                                                      "HKQuantityTypeIdentifierWalkingHeartRateAverage"])]
heart_rate_df.to_csv('heart_rate.csv', index=False)

# %%
heart_rate_df.head(10)
# Out:
#                                   type        sourceName       unit  \
# 110  HKQuantityTypeIdentifierHeartRate  Yu’s Apple Watch  count/min
# 111  HKQuantityTypeIdentifierHeartRate  Yu’s Apple Watch  count/min
# 112  HKQuantityTypeIdentifierHeartRate  Yu’s Apple Watch  count/min
# 113  HKQuantityTypeIdentifierHeartRate  Yu’s Apple Watch  count/min
# 114  HKQuantityTypeIdentifierHeartRate  Yu’s Apple Watch  count/min
# 115  HKQuantityTypeIdentifierHeartRate  Yu’s Apple Watch  count/min
# 116  HKQuantityTypeIdentifierHeartRate  Yu’s Apple Watch  count/min
# 117  HKQuantityTypeIdentifierHeartRate  Yu’s Apple Watch  count/min
# 118  HKQuantityTypeIdentifierHeartRate  Yu’s Apple Watch  count/min
# 119  HKQuantityTypeIdentifierHeartRate  Yu’s Apple Watch  count/min
#
#                   creationDate                  startDate  \
# 110  2019-08-29 19:45:48 -0800  2019-08-29 19:45:14 -0800
# 111  2019-08-29 19:50:33 -0800  2019-08-29 19:47:20 -0800
# 112  2019-08-29 19:56:00 -0800  2019-08-29 19:53:11 -0800
# 113  2019-08-29 20:02:50 -0800  2019-08-29 19:57:39 -0800
# 114  2019-08-29 20:07:01 -0800  2019-08-29 20:03:24 -0800
# 115  2019-08-29 20:11:53 -0800  2019-08-29 20:05:47 -0800
# 116  2019-08-29 21:34:31 -0800  2019-08-29 20:10:58 -0800
# 117  2019-08-29 21:34:37 -0800  2019-08-29 21:34:36 -0800
# 118  2019-08-29 21:34:37 -0800  2019-08-29 21:34:37 -0800
# 119  2019-08-29 21:34:39 -0800  2019-08-29 21:34:38 -0800
#
#                        endDate value
# 110  2019-08-29 19:45:14 -0800    93
# 111  2019-08-29 19:47:20 -0800    89
# 112  2019-08-29 19:53:11 -0800    87
# 113  2019-08-29 19:57:39 -0800    78
# 114  2019-08-29 20:03:24 -0800    84
# 115  2019-08-29 20:05:47 -0800    82
# 116  2019-08-29 20:10:58 -0800    79
# 117  2019-08-29 21:34:36 -0800    86
# 118  2019-08-29 21:34:37 -0800    84
# 119  2019-08-29 21:34:38 -0800    85

# %%
energy_df = record_df.loc[record_df['type'].isin(["HKQuantityTypeIdentifierActiveEnergyBurned", 
                                                  "HKQuantityTypeIdentifierBasalEnergyBurned"])]
energy_df.to_csv('energy.csv', index=False)

# %%
energy_df.head(10)
# Out:
#                                              type        sourceName  unit  \
# 250892  HKQuantityTypeIdentifierBasalEnergyBurned  Yu’s Apple Watch  kcal
# 250893  HKQuantityTypeIdentifierBasalEnergyBurned  Yu’s Apple Watch  kcal
# 250894  HKQuantityTypeIdentifierBasalEnergyBurned  Yu’s Apple Watch  kcal
# 250895  HKQuantityTypeIdentifierBasalEnergyBurned  Yu’s Apple Watch  kcal
# 250896  HKQuantityTypeIdentifierBasalEnergyBurned  Yu’s Apple Watch  kcal
# 250897  HKQuantityTypeIdentifierBasalEnergyBurned  Yu’s Apple Watch  kcal
# 250898  HKQuantityTypeIdentifierBasalEnergyBurned  Yu’s Apple Watch  kcal
# 250899  HKQuantityTypeIdentifierBasalEnergyBurned  Yu’s Apple Watch  kcal
# 250900  HKQuantityTypeIdentifierBasalEnergyBurned  Yu’s Apple Watch  kcal
# 250901  HKQuantityTypeIdentifierBasalEnergyBurned  Yu’s Apple Watch  kcal
#
#                      creationDate                  startDate  \
# 250892  2019-01-13 17:56:37 -0800  2019-01-13 17:34:50 -0800
# 250893  2019-01-13 18:09:18 -0800  2019-01-13 17:49:58 -0800
# 250894  2019-08-30 12:09:15 -0800  2019-01-13 18:04:57 -0800
# 250895  2019-08-30 12:09:15 -0800  2019-08-30 07:25:27 -0800
# 250896  2019-08-30 12:09:15 -0800  2019-08-30 07:40:23 -0800
# 250897  2019-08-30 12:09:15 -0800  2019-08-30 07:55:22 -0800
# 250898  2019-08-30 12:09:15 -0800  2019-08-30 08:10:20 -0800
# 250899  2019-08-30 12:09:15 -0800  2019-08-30 08:25:29 -0800
# 250900  2019-08-30 12:09:15 -0800  2019-08-30 08:25:49 -0800
# 250901  2019-08-30 12:09:15 -0800  2019-08-30 09:25:49 -0800
#
#                           endDate    value
# 250892  2019-01-13 17:49:58 -0800    14.45
# 250893  2019-01-13 18:04:57 -0800   15.375
# 250894  2019-08-30 07:25:27 -0800  9546.56
# 250895  2019-08-30 07:40:23 -0800   16.512
# 250896  2019-08-30 07:55:22 -0800   15.372
# 250897  2019-08-30 08:10:20 -0800   16.325
# 250898  2019-08-30 08:25:29 -0800   16.162
# 250899  2019-08-30 08:25:49 -0800     0.39
# 250900  2019-08-30 09:25:49 -0800   52.732
# 250901  2019-08-30 09:50:23 -0800   21.583

# %%
activity_df = record_df.loc[record_df['type'].isin(["HKQuantityTypeIdentifierStepCount",
                                                    "HKQuantityTypeIdentifierFlightsClimbed", 
                                                    "HKQuantityTypeIdentifierDistanceWalkingRunning"])]
activity_df.to_csv('activity.csv', index=False)

# %%
activity_df.head(10)
# Out:
#                                     type sourceName   unit  \
# 84694  HKQuantityTypeIdentifierStepCount     iPhone  count
# 84695  HKQuantityTypeIdentifierStepCount     iPhone  count
# 84696  HKQuantityTypeIdentifierStepCount     iPhone  count
# 84697  HKQuantityTypeIdentifierStepCount     iPhone  count
# 84698  HKQuantityTypeIdentifierStepCount     iPhone  count
# 84699  HKQuantityTypeIdentifierStepCount     iPhone  count
# 84700  HKQuantityTypeIdentifierStepCount     iPhone  count
# 84701  HKQuantityTypeIdentifierStepCount     iPhone  count
# 84702  HKQuantityTypeIdentifierStepCount     iPhone  count
# 84703  HKQuantityTypeIdentifierStepCount     iPhone  count
#
#                     creationDate                  startDate  \
# 84694  2015-02-17 19:16:08 -0800  2015-02-17 03:38:28 -0800
# 84695  2015-02-17 19:16:08 -0800  2015-02-17 04:12:29 -0800
# 84696  2015-02-17 19:16:08 -0800  2015-02-17 04:12:44 -0800
# 84697  2015-02-17 19:16:08 -0800  2015-02-17 04:12:46 -0800
# 84698  2015-02-17 19:16:08 -0800  2015-02-17 08:05:00 -0800
# 84699  2015-02-17 19:16:08 -0800  2015-02-17 08:05:03 -0800
# 84700  2015-02-17 19:16:08 -0800  2015-02-17 08:05:10 -0800
# 84701  2015-02-17 19:16:08 -0800  2015-02-17 17:39:47 -0800
# 84702  2015-02-17 19:16:08 -0800  2015-02-17 17:39:57 -0800
# 84703  2015-02-17 19:16:08 -0800  2015-02-17 18:18:30 -0800
#
#                          endDate value
# 84694  2015-02-17 03:38:31 -0800    14
# 84695  2015-02-17 04:12:31 -0800    12
# 84696  2015-02-17 04:12:46 -0800     6
# 84697  2015-02-17 04:12:49 -0800     1
# 84698  2015-02-17 08:05:03 -0800     6
# 84699  2015-02-17 08:05:05 -0800     4
# 84700  2015-02-17 08:05:13 -0800     7
# 84701  2015-02-17 17:39:52 -0800     3
# 84702  2015-02-17 17:40:02 -0800    14
# 84703  2015-02-17 18:18:33 -0800    10

# %%
active_time_df = record_df.loc[record_df['type'].isin(["HKQuantityTypeIdentifierAppleExerciseTime", 
                                                       "HKQuantityTypeIdentifierAppleStandTime"])]
active_time_df.to_csv('active_time.csv', index=False)

# %%
active_time_df.head(10)
# Out:
#                                              type        sourceName unit  \
# 600448  HKQuantityTypeIdentifierAppleExerciseTime  Yu’s Apple Watch  min
# 600449  HKQuantityTypeIdentifierAppleExerciseTime  Yu’s Apple Watch  min
# 600450  HKQuantityTypeIdentifierAppleExerciseTime  Yu’s Apple Watch  min
# 600451  HKQuantityTypeIdentifierAppleExerciseTime  Yu’s Apple Watch  min
# 600452  HKQuantityTypeIdentifierAppleExerciseTime  Yu’s Apple Watch  min
# 600453  HKQuantityTypeIdentifierAppleExerciseTime  Yu’s Apple Watch  min
# 600454  HKQuantityTypeIdentifierAppleExerciseTime  Yu’s Apple Watch  min
# 600455  HKQuantityTypeIdentifierAppleExerciseTime  Yu’s Apple Watch  min
# 600456  HKQuantityTypeIdentifierAppleExerciseTime  Yu’s Apple Watch  min
# 600457  HKQuantityTypeIdentifierAppleExerciseTime  Yu’s Apple Watch  min
#
#                      creationDate                  startDate  \
# 600448  2019-08-30 07:36:42 -0800  2019-08-30 07:34:54 -0800
# 600449  2019-08-30 07:37:46 -0800  2019-08-30 07:35:54 -0800
# 600450  2019-08-30 07:38:27 -0800  2019-08-30 07:37:19 -0800
# 600451  2019-08-30 07:39:31 -0800  2019-08-30 07:38:19 -0800
# 600452  2019-08-30 07:46:04 -0800  2019-08-30 07:41:58 -0800
# 600453  2019-08-30 08:11:22 -0800  2019-08-30 08:07:09 -0800
# 600454  2019-08-31 10:40:42 -0800  2019-08-31 10:36:11 -0800
# 600455  2019-08-31 10:40:42 -0800  2019-08-31 10:37:11 -0800
# 600456  2019-08-31 12:43:12 -0800  2019-08-31 12:41:24 -0800
# 600457  2019-08-31 13:52:40 -0800  2019-08-31 13:51:32 -0800
#
#                           endDate value
# 600448  2019-08-30 07:35:54 -0800     1
# 600449  2019-08-30 07:36:54 -0800     1
# 600450  2019-08-30 07:38:19 -0800     1
# 600451  2019-08-30 07:39:19 -0800     1
# 600452  2019-08-30 07:42:58 -0800     1
# 600453  2019-08-30 08:08:09 -0800     1
# 600454  2019-08-31 10:37:11 -0800     1
# 600455  2019-08-31 10:38:11 -0800     1
# 600456  2019-08-31 12:42:24 -0800     1
# 600457  2019-08-31 13:52:32 -0800     1

# %%
workout_df.head(10)
# Out:
#                                                type           duration  \
# 0  HKWorkoutActivityTypeTraditionalStrengthTraining  2.038662616411845
# 1  HKWorkoutActivityTypeTraditionalStrengthTraining   16.9852432012558
# 2  HKWorkoutActivityTypeTraditionalStrengthTraining  2.130942714214325
# 3  HKWorkoutActivityTypeTraditionalStrengthTraining  2.085643335183462
# 4  HKWorkoutActivityTypeTraditionalStrengthTraining  1.923131616910299
# 5  HKWorkoutActivityTypeTraditionalStrengthTraining  2.026056496302287
# 6  HKWorkoutActivityTypeTraditionalStrengthTraining  2.031076717376709
# 7  HKWorkoutActivityTypeTraditionalStrengthTraining  2.129126334190369
# 8  HKWorkoutActivityTypeTraditionalStrengthTraining  2.089483785629272
# 9  HKWorkoutActivityTypeTraditionalStrengthTraining  1.930689167976379
#
#   durationUnit totalDistance totalDistanceUnit totalEnergyBurned  \
# 0          min             0                km                 9
# 1          min             0                km               112
# 2          min             0                km                10
# 3          min             0                km                 9
# 4          min             0                km                 9
# 5          min             0                km                 9
# 6          min             0                km                 9
# 7          min             0                km                10
# 8          min             0                km                 9
# 9          min             0                km                 9
#
#   totalEnergyBurnedUnit        sourceName               creationDate  \
# 0                  kcal  Yu’s Apple Watch  2019-12-21 01:04:21 -0800
# 1                  kcal  Yu’s Apple Watch  2019-12-21 01:04:21 -0800
# 2                  kcal  Yu’s Apple Watch  2019-12-21 01:04:21 -0800
# 3                  kcal  Yu’s Apple Watch  2019-12-21 01:04:21 -0800
# 4                  kcal  Yu’s Apple Watch  2019-12-21 01:04:21 -0800
# 5                  kcal  Yu’s Apple Watch  2019-12-21 01:04:21 -0800
# 6                  kcal  Yu’s Apple Watch  2019-12-21 01:04:21 -0800
# 7                  kcal  Yu’s Apple Watch  2019-12-21 01:04:21 -0800
# 8                  kcal  Yu’s Apple Watch  2019-12-21 01:04:21 -0800
# 9                  kcal  Yu’s Apple Watch  2019-12-21 01:04:21 -0800
#
#                    startDate                    endDate
# 0  2019-12-21 01:01:30 -0800  2019-12-21 01:04:20 -0800
# 1  2019-12-21 01:01:30 -0800  2019-12-21 01:04:20 -0800
# 2  2019-12-21 01:01:30 -0800  2019-12-21 01:04:20 -0800
# 3  2019-12-21 01:01:30 -0800  2019-12-21 01:04:20 -0800
# 4  2019-12-21 01:01:30 -0800  2019-12-21 01:04:20 -0800
# 5  2019-12-21 01:01:30 -0800  2019-12-21 01:04:20 -0800
# 6  2019-12-21 01:01:30 -0800  2019-12-21 01:04:20 -0800
# 7  2019-12-21 01:01:30 -0800  2019-12-21 01:04:20 -0800
# 8  2019-12-21 01:01:30 -0800  2019-12-21 01:04:20 -0800
# 9  2019-12-21 01:01:30 -0800  2019-12-21 01:04:20 -0800

# %%
workout_df.to_csv('workout.csv', index=False)

# %%
summary_df.head(10)
# Out:
#          date activeEnergyBurned activeEnergyBurnedGoal  \
# 0  1969-12-30                  0                      0
# 1  1969-12-31                  0                      0
# 2  2019-01-12                  0                      0
# 3  2019-01-13              2.289                      0
# 4  2019-08-28                  0                      0
# 5  2019-08-29                  0                    270
# 6  2019-08-30            227.007                    270
# 7  2019-08-31            282.434                    270
# 8  2019-09-01            314.599                    500
# 9  2019-09-02            168.857                    350
#
#   activeEnergyBurnedUnit exerciseTime exerciseTimeGoal standHours  \
# 0                   kcal            0             None          0
# 1                   kcal            0             None          0
# 2                   kcal            0             None          0
# 3                   kcal            0             None          0
# 4                   kcal            0             None          0
# 5                   kcal            0             None          2
# 6                   kcal            6             None         12
# 7                   kcal            8             None         13
# 8                   kcal            7             None         14
# 9                   kcal            0             None         11
#
#   standHoursGoal
# 0             12
# 1             12
# 2             12
# 3             12
# 4             12
# 5             12
# 6             12
# 7             12
# 8             12
# 9             12

# %%
summary_df.to_csv('daily_summary.csv', index=False)
